# %% [markdown]
# # Load Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("student.csv")

print("\nOriginal Dataset\n")
print(df)
# Out:
# Original Dataset
#
#      Name   Age   Salary  Gender Department
# 0   Anwar  22.0  25000.0    Male        CSE
# 1    Himo   NaN  30000.0    Male        CSE
# 2   Karim  25.0      NaN    Male        EEE
# 3    Nila  23.0  28000.0  Female        NaN
# 4   Rahim   NaN  35000.0    Male        CSE
# 5    Mitu  21.0      NaN  Female        BBA
# 6  Sabbir  24.0  40000.0     NaN        CSE
# 7     Jui  22.0  27000.0  Female        BBA
# 8  Tanvir   NaN  50000.0    Male        NaN
# 9  Nusrat  23.0  32000.0  Female        CSE

# %% [markdown]
#  Dataset Information

# %%
print("\nDataset Info\n")
print(df.info())
# Out:
# Dataset Info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         7 non-null      float64
#  2   Salary      8 non-null      float64
#  3   Gender      9 non-null      object
#  4   Department  8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes
# None

# %% [markdown]
# # Missing Value Detection

# %%
print("\nMissing Value Check\n")
print(df.isnull())
# Out:
# Missing Value Check
#
#     Name    Age  Salary  Gender  Department
# 0  False  False   False   False       False
# 1  False   True   False   False       False
# 2  False  False    True   False       False
# 3  False  False   False   False        True
# 4  False   True   False   False       False
# 5  False  False    True   False       False
# 6  False  False   False    True       False
# 7  False  False   False   False       False
# 8  False   True   False   False        True
# 9  False  False   False   False       False

# %% [markdown]
# # Column-wise Missing Count

# %%
print("\nMissing Count\n")
print(df.isnull().sum())
# Out:
# Missing Count
#
# Name          0
# Age           3
# Salary        2
# Gender        1
# Department    2
# dtype: int64

# %% [markdown]
# # Total Missing Values

# %%
print("\nTotal Missing Values\n")
print(df.isnull().sum().sum())
# Out:
# Total Missing Values
#
# 0

# %% [markdown]
# # Fill Missing Numeric Values

# %%
# Age -> Mean
df["Age"] = df["Age"].fillna(df["Age"].mean())

# Salary -> Median
df["Salary"] = df["Salary"].fillna(df["Salary"].median())

# Gender -> Mode
df["Gender"] = df["Gender"].fillna(df["Gender"].mode()[0])

# Department -> Mode
df["Department"] = df["Department"].fillna(df["Department"].mode()[0])
# Dataset After Filling

print("\nDataset After Filling Missing Values\n")
print(df)
# Out:
# Dataset After Filling Missing Values
#
#      Name        Age   Salary  Gender Department
# 0   Anwar  22.000000  25000.0    Male        CSE
# 1    Himo  22.857143  30000.0    Male        CSE
# 2   Karim  25.000000  31000.0    Male        EEE
# 3    Nila  23.000000  28000.0  Female        CSE
# 4   Rahim  22.857143  35000.0    Male        CSE
# 5    Mitu  21.000000  31000.0  Female        BBA
# 6  Sabbir  24.000000  40000.0    Male        CSE
# 7     Jui  22.000000  27000.0  Female        BBA
# 8  Tanvir  22.857143  50000.0    Male        CSE
# 9  Nusrat  23.000000  32000.0  Female        CSE

# %% [markdown]
# # Heatmap Visualization

# %%
plt.figure(figsize=(8, 5))

sns.heatmap(df.isnull(), cbar=True)

plt.title("Missing Value Heatmap")

plt.show()
