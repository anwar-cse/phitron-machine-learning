# %% [markdown]
# # LOAD DATA FROM CSV FILE

# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %% [markdown]
# show data

# %%
print(df)
# Out:
#    ID    Name             Email  Phone  Salary
# 0   1   Rahim   rahim@gmail.com   1711   25000
# 1   2   Karim   karim@gmail.com   1822   30000
# 2   2   Karim   karim@gmail.com   1822   30000
# 3   3   Anika   anika@gmail.com   1933   28000
# 4   4  Sabbir  sabbir@gmail.com   1644   35000
# 5   5  Nusrat  nusrat@gmail.com   1555   40000
# 6   5  Nusrat  nusrat@gmail.com   1555   40000

# %% [markdown]
# shape

# %%
print(df.shape)
# Out:
# (7, 5)

# %% [markdown]
# duplicate,count duplicate, show duplicate row, remove duplicate,

# %%
print(df.duplicated())
print(df.duplicated().sum())
print(df[df.duplicated()])
print(df.drop_duplicates())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool
# 2
#    ID    Name             Email  Phone  Salary
# 2   2   Karim   karim@gmail.com   1822   30000
# 6   5  Nusrat  nusrat@gmail.com   1555   40000
#    ID    Name             Email  Phone  Salary
# 0   1   Rahim   rahim@gmail.com   1711   25000
# 1   2   Karim   karim@gmail.com   1822   30000
# 3   3   Anika   anika@gmail.com   1933   28000
# 4   4  Sabbir  sabbir@gmail.com   1644   35000
# 5   5  Nusrat  nusrat@gmail.com   1555   40000

# %% [markdown]
# email duplicate, keep parameter,
